# %% [markdown]
# # Demystifying Python installations
#
# ### How we go from this

# %%
from IPython.core.display import Image 
Image(url='https://imgs.xkcd.com/comics/python_environment.png')
# Out:
# <img src="https://imgs.xkcd.com/comics/python_environment.png"/>

# %% [markdown]
# ### To this

# %%
Image(url='https://imgs.xkcd.com/comics/python.png')
# Out:
# <img src="https://imgs.xkcd.com/comics/python.png"/>

# %% [markdown]
# (Python easter egg, try running `import antigravity` in your Python interpreter of choice)

# %% [markdown]
# Geting started with Python can be bewildering due to the shear number of options for package management and code editing. Do I install with pip or Anaconda? Should I try homebrew? Which Python version should I use? Can I write my code in Jupyter then copy it over to Spyder? Why doesn't Pycharm find my science packages?
#
# In this notebook, I will give an overview of some of the most popular Python installions and why you may want to use one over another (or several in parralel).

# %% [markdown]
# ### tl;dr: how should I install Python?
# 1. Get [Anaconda for Python](https://www.anaconda.com/distribution/) (make sure it's Python 3.x not 2.x) and install it on your computer
# 2. Follow the instructions for this [ppd course](https://github.com/callumrollo/ppd_python/blob/master/README.md) to build the ppd_python environement
# 3. Download [Pycharm](https://www.jetbrains.com/pycharm/)
# 4. in Pycharm, [create a new project](https://medium.com/infinity-aka-aseem/how-to-setup-pycharm-with-an-anaconda-virtual-environment-already-created-fb927bacbe61) using the conda environment `ppd_python` that you built in step 2
# 5. Start writing Python code

# %% [markdown]
# ### The long read. Why do you recommend this setup?
#
# There are as many answers to this question as there are ways to install Python (that's rather a lot). This is largely due to the nature of Python. It is a free software project with open source code that anyone can fork to make their own ideal Python ecosystem.
#
# If you were so inclined, you could download the [Python source code](https://www.python.org/downloads/source/) and build it from scratch in whatever way you see fit. While very freeing, this is a difficult and tedious task. If your aim is to write Python code, you can download a free Python distribution optimised for that task.
#
# I use Anaconda for Python because it is optimised for scientific Python, with the most popular sience packages immediatly available and eveything else available through pip. Additonally, Anaconda keeps my environments safe and seperate and prevents me from inadvertantly wrecking my Python installation.

# %% [markdown]
# ### Beyond the basics
# When you start needing modules beyond the core of Anaconda and the [extra modules from ppd_python](https://github.com/callumrollo/ppd_python/blob/master/environment.yml). You will need to start searching for way ton install cool new packages

# %% [markdown]
# ### pip vs Anaconda
# If you start searching for Python packages, you will soon encounter [pip](https://pypi.org/project/pip/)
#
# In helpful free software tradition, pip is a recursive acronym:
#
# Pip
# Installs
# Packages
#
# Similar to its free software friends cURL (Curl URL Request Library), WINE (Wine is Not an Emulator),  (GNU (Gnu's Not UNIX) and yaml (Yaml Ain't Markup Language).
#
# Pip does what it says on the tin. It will fetch and install any package you ask for from the enormous [Python Package Index](https://pypi.org/). Over 200'000 packages are available. If you have a problem, someone has almost certainly written the solution and it's on PyPI somewhere.
#
# With such a wealth of packages available, why would we use Anaconda, with its palty 1500 packages, rather than pip?
#
# The answer is that Anaconda is a true *distribution*. It handles everything for us and saves us from making the kind of mess in the xkcd comic at the beginning of this document.
#
# So, how does Anaconda work?

# %%
Image(url='https://protostar.space/wp-content/uploads/2019/04/conda-root-and-additional-environments.jpeg')
# Out:
# <img src="https://protostar.space/wp-content/uploads/2019/04/conda-root-and-additional-environments.jpeg"/>

# %% [markdown]
# Image(url='https://protostar.space/wp-content/uploads/2019/04/conda-root-and-additional-environments.jpeg')

# %% [markdown]
# ### Workflow for safely installing a new package:
# 1. Create a basic environment file (you can start by copying the environment.yaml filfe from this repo) with everything you'll need for your project (numpy for maths, matplotlib for plotting, xarray for netCDFs etc.) and give it a sensible name
# 2. Create and activate this environment just like you did for ppd_python
# 3. Once you have activated your environment, you can add extra packages easily with `conda install <package name>`
# If the package you want is not yet available through Anaconda, you can get it with pip.
# First install pip with `conda install pip`. Then use pip to install the package you need with `pip install <package name>`

# %% [markdown]
# ### Why is it important to build distinct environments?
#
# By creating a new environment for each project we work on, we ensure that we avoid package conflicts later. Package conflicts come about because most packages rely on code from others (this is called a dependency in programming).
#
# For example [pandas](https://pandas.pydata.org/pandas-docs/stable/install.html) has many dependencies. Icluding numpy version 1.13.3 or higher.
#
# You can only have one version of NumPy active, so, if another package you need depends on an old version of NumPy (this could easily be the case if someone wrote some scientific code back in 2015 and hasn't updated it since) you will not be able to run the latest version of pandas and your legacy package together.
#
# If we were to simply run conda install `package name` in our core environment every time we wanted to try out a new package, we sould soon run in to problems.
#
# What Anaconda allows us to do is make many different environments on our computer. Each environment is completely independant and can have
# - Different packages
# - Different versions of the same package
# - Different versions of Python itself
#
# This massivly increases our flexibility and allows to install any package and experiment with different Python setups without fear of beraking our Python install

# %% [markdown]
# ### Excercise:
# Imagine we wanted to make use of the [cool new features of python 3.8](https://medium.com/fintechexplained/awesome-new-python-3-8-features-ed027416f2a5) in your code
#
# #### 1. Make a new environment called testing with python 3.8 and numpy
#
# You can do this by making a environment.yaml file like this:
# ```yaml
# name: testing
# dependencies:
#    - python=3.8
#    - numpy
#
# ```
# and creating the environment as you did for ppd_python
#
# #### 2. Activate the environment `testing`

# %% [markdown]
# On another project you want to make some plots with matplotlib.
#
# #### 3. Try installing matplotlib in the testing environment with
# `conda install matplotlib`
#
# What happened!?

# %% [markdown]
# If we were using Python by itself we would have to decide, Python 3.8 and numpy or matplotlib?
#
# With anaconda, we can have both
#
# #### 4. Make a new environment with python, numpy and matplotlib, do not specify the version of python
#
# ```yaml
# name: testing2
# dependencies:
#    - python
#    - numpy
#    - matplotlib
#
# ```

# %% [markdown]
# ### Take home messages:
# - Environments let you set up any combination of libraries without affecting your base installation
# - Specifying version numbers (e.g. python=3.8) decreases your flexibility and increases the chance of conflicts. Only do it if you really need to

# %% [markdown]
# -----------------------------------
# This is my personal take on the Python ecosystem and the best way to naviate it, there are many more opinions on the internet.
#
# For more detail, here's a [nicely illustrated article](https://protostar.space/why-you-need-python-environments-and-how-to-manage-them-with-conda) on how to manage Anaconda. this is the source of the image I used earlier in this notebook
